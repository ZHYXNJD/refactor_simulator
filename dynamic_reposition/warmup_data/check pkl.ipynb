# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pickle as pkl
import pandas as pd
import numpy as np

# %%
with open('grid_263_freq_10_repo_state.pkl','rb') as f:
    state_dt = pkl.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
#       1 with open('grid_263_freq_10_repo_state.pkl','rb') as f:
# ----> 2     state_dt = pkl.load(f)
#
# ModuleNotFoundError: No module named 'dynamic_reposition'
